# %% [markdown]
# <a href="https://colab.research.google.com/github/Murali23130/DAV_Project_130/blob/main/DavAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("IPLPlayerAuctionData.csv")

# Displaying first 5 rows
print("Displaying first 5 rows of the dataset:")
print(df.head())

# Data types and shape
print("\nData types of the columns:")
print(df.dtypes)

rows, cols = df.shape
print(f"\nShape of the dataset:\nNo. of rows: {rows}, No. of columns: {cols}\n")
# Out:
# Displaying first 5 rows of the dataset:
#         Player     Role    Amount                         Team    Year  \
# 0  Aaron Finch  Batsman  40000000          Sunrisers Hyderabad  2014.0
# 1  Aaron Finch  Batsman  32000000               Mumbai Indians  2015.0
# 2  Aaron Finch  Batsman  10000000                Gujarat Lions  2016.0
# 3  Aaron Finch  Batsman  62000000              Kings XI Punjab  2018.0
# 4  Aaron Finch  Batsman  44000000  Royal Challengers Bangalore  2020.0
#
#   Player Origin
# 0      Overseas
# 1      Overseas
# 2      Overseas
# 3      Overseas
# 4      Overseas
#
# Data types of the columns:
# Player            object
# Role              object
# Amount             int64
# Team              object
# Year             float64
# Player Origin     object
# dtype: object
#
# Shape of the dataset:
# No. of rows: 970, No. of columns: 6

# %%
# Creating numpy array from 'Amount' column
amount = np.array(df['Amount'])
print("Numpy array of Amount column:", amount[:5])

# Array Indexing
print("First element in Amount array:", amount[0])
print("Last element in Amount array:", amount[-1])

# Array Slicing
print("Amount elements from index 2 to 5:", amount[2:5])

# Reshape array
print("Original shape of Amount array:", amount.shape)
reshaped_amount = amount.reshape(len(amount), 1)
print("Reshaped Amount array (first 5 rows):\n", reshaped_amount[:5])
# Out:
# Numpy array of Amount column: [40000000 32000000 10000000 62000000 44000000]
# First element in Amount array: 40000000
# Last element in Amount array: 6000000
# Amount elements from index 2 to 5: [10000000 62000000 44000000]
# Original shape of Amount array: (970,)
# Reshaped Amount array (first 5 rows):
#  [[40000000]
#  [32000000]
#  [10000000]
#  [62000000]
#  [44000000]]

# %%
# Concatenation and Splitting
concatenated = np.concatenate((amount[:5], [10000000, 15000000]))
print("Concatenated array:", concatenated)

split_amount = np.array_split(amount, 2)
print("Split arrays (first part):", split_amount[0][:5])
print("Split arrays (second part):", split_amount[1][:5])

# Universal Functions
squared_amount = np.square(amount)
print("Squared Amount values (first 5):", squared_amount[:5])

# Aggregation
mean_amount = np.mean(amount)
max_amount = np.max(amount)
print("Mean Amount:", mean_amount)
print("Max Amount:", max_amount)

# Broadcasting
plus_10m = amount + 10000000
print("Amount plus 10 million (first 5):", plus_10m[:5])

# Comparisons
high_value = amount > 50000000
print("Boolean array for Amount > 50 million:\n", high_value[:10])

# Boolean Masks
high_value_players = amount[high_value]
print("Amounts greater than 50 million (first 10):", high_value_players[:10])

# Fancy Indexing
indices = [0, 5, 10]
print("Amounts at indices 0, 5, 10:", amount[indices])

# Sorting
sorted_amount = np.sort(amount)
print("Sorted Amounts (first 5):", sorted_amount[:5])

indices_by_amount = np.argsort(amount)
print("Indices sorted by Amount (first 5):", indices_by_amount[:5])
print("Sorted values (first 5):", amount[indices_by_amount[:5]])
# Out:
# Concatenated array: [40000000 32000000 10000000 62000000 44000000 10000000 15000000]
# Split arrays (first part): [40000000 32000000 10000000 62000000 44000000]
# Split arrays (second part): [ 9500000  1000000 11000000  2000000  2000000]
# Squared Amount values (first 5): [1600000000000000 1024000000000000  100000000000000 3844000000000000
#  1936000000000000]
# Mean Amount: 21054510.30927835
# Max Amount: 162500000
# Amount plus 10 million (first 5): [50000000 42000000 20000000 72000000 54000000]
# Boolean array for Amount > 50 million:
#  [False False False  True False False False False False False]
# Amounts greater than 50 million (first 10): [ 62000000  50625000  65000000  54375000  67500000  72000000  75000000
#   55000000 100000000 145000000]
# Amounts at indices 0, 5, 10: [40000000  2000000 50625000]
# Sorted Amounts (first 5): [1000000 1000000 1000000 1000000 1000000]
# Indices sorted by Amount (first 5): [ 33 936  69  70 787]
# Sorted values (first 5): [1000000 1000000 1000000 1000000 1000000]

# %%
# Pandas Operations
print("\nPandas Operations\n")

# Series Object
player_series = pd.Series(df['Player'])
print("Pandas Series of Players (first 5):")
print(player_series.head())

# DataFrame Info
print("\nDataFrame Info:")
df.info()

# Series Indexing
print("\nFirst player:", player_series[0])
print("Players from index 2 to 4:")
print(player_series[2:5])
# Out:
# Pandas Operations
#
# Pandas Series of Players (first 5):
# 0    Aaron Finch
# 1    Aaron Finch
# 2    Aaron Finch
# 3    Aaron Finch
# 4    Aaron Finch
# Name: Player, dtype: object
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         970 non-null    object
#  1   Role           970 non-null    object
#  2   Amount         970 non-null    int64
#  3   Team           970 non-null    object
#  4   Year           969 non-null    float64
#  5   Player Origin  970 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 45.6+ KB
#
# First player: Aaron Finch
# Players from index 2 to 4:
# 2    Aaron Finch
# 3    Aaron Finch
# 4    Aaron Finch
# Name: Player, dtype: object

# %%
# DataFrame Indexing
print("\nDataFrame with only 'Player' and 'Amount' columns:")
print(df[['Player', 'Amount']].head())

print("\nRow at index 1 of the DataFrame:")
print(df.loc[1])

print("\nValue in 'Team' column at index 3:")
print(df.iloc[3, df.columns.get_loc('Team')])

# Mapping / Transformation
def add_prefix(x):
    return "Origin: " + x

origin_with_prefix = df['Player Origin'].map(add_prefix)
print("\nPlayer Origin with prefix (first 5):")
print(origin_with_prefix.head())

# Series Addition
amount_series = pd.Series(df['Amount'].values, index=df['Player'])
year_series = pd.Series(df['Year'].values, index=df['Player'])
combined_series = amount_series + year_series
print("\nAmount + Year (first 5):")
print(combined_series.head())
# Out:
# DataFrame with only 'Player' and 'Amount' columns:
#         Player    Amount
# 0  Aaron Finch  40000000
# 1  Aaron Finch  32000000
# 2  Aaron Finch  10000000
# 3  Aaron Finch  62000000
# 4  Aaron Finch  44000000
#
# Row at index 1 of the DataFrame:
# Player              Aaron Finch
# Role                    Batsman
# Amount                 32000000
# Team             Mumbai Indians
# Year                     2015.0
# Player Origin          Overseas
# Name: 1, dtype: object
#
# Value in 'Team' column at index 3:
# Kings XI Punjab
#
# Player Origin with prefix (first 5):
# 0    Origin: Overseas
# 1    Origin: Overseas
# 2    Origin: Overseas
# 3    Origin: Overseas
# 4    Origin: Overseas
# Name: Player Origin, dtype: object
#
# Amount + Year (first 5):
# Player
# Aaron Finch    40002014.0
# Aaron Finch    32002015.0
# Aaron Finch    10002016.0
# Aaron Finch    62002018.0
# Aaron Finch    44002020.0
# dtype: float64

# %%
# Null Values
print("\nChecking for null values:")
print(df.isnull().sum())

# Hierarchical Indexing
hierarchical_df = df.set_index(['Player', 'Team'])
print("\nDataFrame with Hierarchical Index:")
print(hierarchical_df.head())

# Creating a second sample DataFrame
df2 = pd.DataFrame({
    'Player': ['MS Dhoni', 'Virat Kohli', 'Rohit Sharma'],
    'Nationality': ['India', 'India', 'India']
})
print("\nSecond DataFrame:")
print(df2)
# Out:
# Checking for null values:
# Player           0
# Role             0
# Amount           0
# Team             0
# Year             1
# Player Origin    0
# dtype: int64
#
# DataFrame with Hierarchical Index:
#                                             Role    Amount    Year  \
# Player      Team
# Aaron Finch Sunrisers Hyderabad          Batsman  40000000  2014.0
#             Mumbai Indians               Batsman  32000000  2015.0
#             Gujarat Lions                Batsman  10000000  2016.0
#             Kings XI Punjab              Batsman  62000000  2018.0
#             Royal Challengers Bangalore  Batsman  44000000  2020.0
#
#                                         Player Origin
# Player      Team
# Aaron Finch Sunrisers Hyderabad              Overseas
#             Mumbai Indians                   Overseas
#             Gujarat Lions                    Overseas
#             Kings XI Punjab                  Overseas
#             Royal Challengers Bangalore      Overseas
#
# Second DataFrame:
#          Player Nationality
# 0      MS Dhoni       India
# 1   Virat Kohli       India
# 2  Rohit Sharma       India

# %%
# Concatenate
concat_df = pd.concat([df.head(3), df2], ignore_index=True)
print("\nConcatenated DataFrame:")
print(concat_df)

# Append (using concat, since append is deprecated)
append_df = pd.concat([df.head(3), df2], ignore_index=True)
print("\nAppended DataFrame:")
print(append_df)


# Merge (Left Join)
merged_df = pd.merge(df, df2, on='Player', how='left')
print("\nMerged DataFrame (Left Join):")
print(merged_df.head())
# Out:
# Concatenated DataFrame:
#          Player     Role      Amount                 Team    Year  \
# 0   Aaron Finch  Batsman  40000000.0  Sunrisers Hyderabad  2014.0
# 1   Aaron Finch  Batsman  32000000.0       Mumbai Indians  2015.0
# 2   Aaron Finch  Batsman  10000000.0        Gujarat Lions  2016.0
# 3      MS Dhoni      NaN         NaN                  NaN     NaN
# 4   Virat Kohli      NaN         NaN                  NaN     NaN
# 5  Rohit Sharma      NaN         NaN                  NaN     NaN
#
#   Player Origin Nationality
# 0      Overseas         NaN
# 1      Overseas         NaN
# 2      Overseas         NaN
# 3           NaN       India
# 4           NaN       India
# 5           NaN       India
#
# Appended DataFrame:
#          Player     Role      Amount                 Team    Year  \
# 0   Aaron Finch  Batsman  40000000.0  Sunrisers Hyderabad  2014.0
# 1   Aaron Finch  Batsman  32000000.0       Mumbai Indians  2015.0
# 2   Aaron Finch  Batsman  10000000.0        Gujarat Lions  2016.0
# 3      MS Dhoni      NaN         NaN                  NaN     NaN
# 4   Virat Kohli      NaN         NaN                  NaN     NaN
# 5  Rohit Sharma      NaN         NaN                  NaN     NaN
#
#   Player Origin Nationality
# 0      Overseas         NaN
# 1      Overseas         NaN
# 2      Overseas         NaN
# 3           NaN       India
# 4           NaN       India
# 5           NaN       India
#
# Merged DataFrame (Left Join):
#         Player     Role    Amount                         Team    Year  \
# 0  Aaron Finch  Batsman  40000000          Sunrisers Hyderabad  2014.0
# 1  Aaron Finch  Batsman  32000000               Mumbai Indians  2015.0
# 2  Aaron Finch  Batsman  10000000                Gujarat Lions  2016.0
# 3  Aaron Finch  Batsman  62000000              Kings XI Punjab  2018.0
# 4  Aaron Finch  Batsman  44000000  Royal Challengers Bangalore  2020.0
#
#   Player Origin Nationality
# 0      Overseas         NaN
# 1      Overseas         NaN
# 2      Overseas         NaN
# 3      Overseas         NaN
# 4      Overseas         NaN

# %%
# Grouping & Aggregation
grouped_avg = df.groupby('Team')['Amount'].mean()
print("\nAverage Amount by Team:")
print(grouped_avg.head())

# Pivot Table
pivot = pd.pivot_table(df, values='Amount', index='Team', columns='Player Origin', aggfunc='mean')
print("\nPivot Table (Average Amount by Team & Origin):")
print(pivot)
# Out:
# Average Amount by Team:
# Team
# Chennai Super Kings    1.892620e+07
# Delhi Capitals         2.071739e+07
# Delhi Daredevils       2.288824e+07
# Gujarat Lions          6.833333e+06
# Gujarat Titans         2.592500e+07
# Name: Amount, dtype: float64
#
# Pivot Table (Average Amount by Team & Origin):
# Player Origin                      Indian      Overseas
# Team
# Chennai Super Kings          1.717000e+07  2.158712e+07
# Delhi Capitals               1.394828e+07  3.226471e+07
# Delhi Daredevils             2.036364e+07  2.751667e+07
# Gujarat Lions                5.360000e+06  1.420000e+07
# Gujarat Titans               2.357692e+07  3.028571e+07
# Kings XI Punjab              1.695370e+07  3.445000e+07
# Kolkata Knight Riders        1.644030e+07  2.659062e+07
# Lucknow Super Giants         2.625000e+07  4.583333e+07
# Mumbai Indians               1.235385e+07  2.540476e+07
# Pune Warriors India          5.062500e+07  4.562500e+07
# Punjab Kings                 1.967500e+07  5.300000e+07
# Rajasthan Royals             1.652941e+07  2.825781e+07
# Rising Pune Supergiant       7.000000e+06  2.933333e+07
# Royal Challengers Bangalore  1.587500e+07  3.596591e+07
# Sunrisers Hyderabad          1.927941e+07  2.272727e+07

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.hist(df['Amount'], bins=20, edgecolor='black')
plt.title('Distribution of Auction Amounts')
plt.xlabel('Amount')
plt.ylabel('Number of Players')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(df['Year'], df['Amount'])
plt.title('Year vs. Auction Amount')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.grid(True)
plt.tight_layout()
plt.show()

team_counts = df['Team'].value_counts()
plt.figure(figsize=(10, 6))
team_counts.plot(kind='bar', edgecolor='black')
plt.title('Number of Players per Team')
plt.xlabel('Team')
plt.ylabel('Number of Players')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
avg_yearly = df.groupby('Year')['Amount'].mean()

plt.figure(figsize=(10, 6))
avg_yearly.plot(marker='o')
plt.title('Average Auction Amount Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Amount')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
df.boxplot(column='Amount', by='Player Origin')
plt.title('Auction Amount by Player Origin')
plt.suptitle('')
plt.xlabel('Player Origin')
plt.ylabel('Amount')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
country_counts = df['Player Origin'].value_counts().head(6)
plt.figure(figsize=(7, 7))
plt.pie(country_counts, labels=country_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 6 Countries by Number of Players')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns

# Load your dataset
df = pd.read_csv("IPLPlayerAuctionData.csv")

# Display column names
print("Columns in the dataset:")
print(df.columns.tolist())

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Team', y='Amount', data=df, hue='Role', alpha=0.7)
plt.title('Team-wise Auction Amount per Player')
plt.xlabel('Team')
plt.ylabel('Auction Amount')
plt.xticks(rotation=45)
plt.legend(title='Role', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Columns in the dataset:
# ['Player', 'Role', 'Amount', 'Team', 'Year', 'Player Origin']

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Year', y='Amount', data=df, palette='cool', inner='point')
plt.title('Auction Amount Distribution Over Years')
plt.xlabel('Year')
plt.ylabel('Auction Amount')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-b24bd569d878>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Year', y='Amount', data=df, palette='cool', inner='point')

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
data = pd.read_csv('IPLPlayerAuctionData.csv')

# Convert 'Amount' to INR Crores (if needed)
data['Amount'] = data['Amount'] / 10**7

# Create boxplot with corrected parameters
plt.figure(figsize=(12, 6))
sns.boxplot(
    x='Role',          # X-axis: Player role
    y='Amount',        # Y-axis: Auction amount
    data=data,         # DataFrame
    hue='Role',        # Assign 'Role' to hue to use palette
    palette='viridis', # Color scheme
    legend=False       # Disable redundant legend
)

# Customize plot
plt.title('Auction Amount Distribution by Player Role', fontsize=14)
plt.xlabel('Player Role', fontsize=12)
plt.ylabel('Auction Amount (INR Cr)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('IPLPlayerAuctionData.csv')

# Convert 'Amount' to INR Crores
data['Amount'] = data['Amount'] / 10**7

# Use only available numerical features (e.g., Year)
numerical_features = [
    'Amount',
    'Year'
]

# Subset data
correlation_data = data[numerical_features]

# Compute correlations
corr_matrix = correlation_data.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap='coolwarm'
)
plt.title('Correlation Between Auction Amount and Year', fontsize=14)
plt.show()
